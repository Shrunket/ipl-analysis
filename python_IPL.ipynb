# %%
import os
import math
import numpy as np
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Samruddhi\\Downloads'

# %%
os.chdir('C:/Users/Samruddhi/Desktop/IPL dataset')

# %%
deliveries= pd.read_csv('deliveries.csv')
matches= pd.read_csv('matches.csv')

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # Most Runs in IPL (2008-2018)

# %%
most_runs= deliveries.groupby(['batsman'])['batsman_runs'].agg('sum')

# %%
most_runs= pd.DataFrame(most_runs)

# %%
most_runs.sort_values(by='batsman_runs',ascending=False).head(10)
# Out:
#                 batsman_runs
# batsman
# V Kohli                 5434
# SK Raina                5415
# RG Sharma               4914
# DA Warner               4741
# S Dhawan                4632
# CH Gayle                4560
# MS Dhoni                4477
# RV Uthappa              4446
# AB de Villiers          4428
# G Gambhir               4223

# %%
#number of matches

# %%
total_matches= len(set(deliveries['match_id']))
total_matches
# Out:
# 756

# %%
match_played= deliveries.groupby(['batsman'])['match_id'].nunique()

# %%
match_played= pd.DataFrame(match_played)

# %%
match_played.sort_values(by='match_id',ascending= False).head(10)
# Out:
#                 match_id
# batsman
# SK Raina             189
# RG Sharma            182
# RV Uthappa           170
# MS Dhoni             170
# V Kohli              169
# KD Karthik           162
# S Dhawan             158
# YK Pathan            153
# G Gambhir            151
# AB de Villiers       142

# %%
most_runs['matches']= match_played['match_id'].values

# %%
# Strike Rate

# %%
ball_faced= deliveries.groupby(['batsman'])['ball'].agg('count')

# %%
ball_faced= pd.DataFrame(ball_faced)

# %%
most_runs['ball_faced']= ball_faced['ball'].values

# %%
most_runs
# Out:
#                       batsman_runs  matches  ball_faced
# batsman
# A Ashish Reddy                 280       23         196
# A Chandila                       4        2           7
# A Chopra                        53        6          75
# A Choudhary                     25        3          20
# A Dananjaya                      4        1           5
# A Flintoff                      62        3          57
# A Hales                        152        6         119
# A Joseph                        15        1          13
# A Kumble                        35       15          49
# A Mishra                       368       54         410
# A Mithun                        34        6          26
# A Mukund                        19        2          23
# A Nehra                         41       17          63
# A Singh                          2        5          10
# A Symonds                      974       36         781
# A Turner                         4        4          11
# ...

# %%
most_runs['strike_rate']= np.nan

# %%
for i in range(0,len(most_runs['batsman_runs'])):
    most_runs['strike_rate'][i]=round((most_runs['batsman_runs'][i]*100) / most_runs['ball_faced'][i],1)
# Out:
# C:\Users\Samruddhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
most_runs
# Out:
#                       batsman_runs  matches  ball_faced  strike_rate
# batsman
# A Ashish Reddy                 280       23         196        142.9
# A Chandila                       4        2           7         57.1
# A Chopra                        53        6          75         70.7
# A Choudhary                     25        3          20        125.0
# A Dananjaya                      4        1           5         80.0
# A Flintoff                      62        3          57        108.8
# A Hales                        152        6         119        127.7
# A Joseph                        15        1          13        115.4
# A Kumble                        35       15          49         71.4
# A Mishra                       368       54         410         89.8
# A Mithun                        34        6          26        130.8
# A Mukund                        19        2          23         82.6
# ...

# %% [markdown]
# # Most Sixes

# %%
most_sixes= deliveries[['batsman','batsman_runs']]

# %%
most_sixes= most_sixes.rename(columns={'batsman_runs':'sixes'})

# %%
yes=most_sixes[most_sixes['sixes']== 6]

# %%
most_sixes= yes.groupby(['batsman'])['sixes'].agg('count')

# %%
most_sixes=pd.DataFrame(most_sixes)

# %%
most_sixes.sort_values(by='sixes',ascending= False).head(10)
# Out:
#                 sixes
# batsman
# CH Gayle          327
# AB de Villiers    214
# MS Dhoni          207
# SK Raina          195
# RG Sharma         194
# V Kohli           191
# DA Warner         181
# SR Watson         177
# KA Pollard        175
# YK Pathan         161

# %% [markdown]
# # Most Fours

# %%
most_fours= deliveries[['batsman','batsman_runs']]

# %%
most_fours= most_fours.rename(columns={'batsman_runs':'fours'})

# %%
fours=most_fours[most_fours['fours']== 4]

# %%
most_fours= fours.groupby(['batsman'])['fours'].agg('count')

# %%
most_fours=pd.DataFrame(most_fours)

# %%
most_fours.sort_values(by='fours',ascending= False).head(10)
# Out:
#             fours
# batsman
# S Dhawan      526
# SK Raina      495
# G Gambhir     492
# V Kohli       482
# DA Warner     459
# RV Uthappa    436
# RG Sharma     431
# AM Rahane     405
# CH Gayle      376
# PA Patel      366

# %% [markdown]
# # Highest Strike Rate (16-20 ovr)

# %%
pro= deliveries.copy()

# %%
ovr_17= pro['over']== 17
ovr_18= pro['over']== 18
ovr_19= pro['over']== 19
ovr_20= pro['over']== 20

# %%
pro=pro[ovr_17 | ovr_18 | ovr_19 | ovr_20]

# %%
runs= pro.groupby(['batsman'])['batsman_runs'].agg('sum')

# %%
runs=pd.DataFrame(runs)

# %%
ball= pro.groupby(['batsman'])['ball'].agg('count')

# %%
ball=pd.DataFrame(ball)

# %%
runs['ball']= ball['ball'].values

# %%
runs['strike_rate']= np.nan

# %%
for i in range(0,len(runs['strike_rate'])):
    runs['strike_rate'][i]= round(((runs['batsman_runs'][i]*100) / runs['ball'][i]),1)
# Out:
# C:\Users\Samruddhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
high_Sr= runs[runs['batsman_runs']>=500].sort_values(by='strike_rate', ascending= False).head(10)

# %%
high_Sr.drop(['batsman_runs','ball'],axis=1, inplace=True)

# %%
high_Sr
# Out:
#                 strike_rate
# batsman
# AB de Villiers        226.5
# AD Russell            207.6
# V Kohli               198.6
# RG Sharma             193.4
# DA Miller             184.0
# MS Dhoni              183.9
# DJ Bravo              182.6
# KD Karthik            177.7
# JP Duminy             177.6
# HH Pandya             175.3

# %% [markdown]
# # Super Over

# %%
sup=deliveries[deliveries['is_super_over']==1]

# %%
sup
# Out:
#         match_id  inning                 batting_team  \
# 8092          34       3               Mumbai Indians
# 8093          34       3               Mumbai Indians
# 8094          34       3               Mumbai Indians
# 8095          34       3               Mumbai Indians
# 8096          34       3               Mumbai Indians
# 8097          34       4                Gujarat Lions
# 8098          34       4                Gujarat Lions
# 8099          34       4                Gujarat Lions
# 8100          34       4                Gujarat Lions
# 8101          34       4                Gujarat Lions
# 8102          34       4                Gujarat Lions
# 8103          34       4                Gujarat Lions
# 8104          34       4                Gujarat Lions
# 29279        126       3        Kolkata Knight Riders
# 29280        126       3        Kolkata Knight Riders
# 29281        126       3        Kolkata Knight Riders
# ...

# %%
so= sup['match_id'].unique()
total_so=len(sup['match_id'].unique())
total_so
# Out:
# 7

# %%
super_over= sup.groupby(['batting_team'])['match_id'].nunique()

# %%
super_over
# Out:
# batting_team
# Chennai Super Kings            1
# Delhi Daredevils               1
# Gujarat Lions                  1
# Kings XI Punjab                2
# Kolkata Knight Riders          2
# Mumbai Indians                 1
# Rajasthan Royals               3
# Royal Challengers Bangalore    2
# Sunrisers Hyderabad            1
# Name: match_id, dtype: int64

# %%
so=matches[matches['result']=='tie']

# %%
so_1= so.iloc[:,4]
so_1=pd.DataFrame(so_1)

# %%
so_2= so.iloc[:,5]
so_2=pd.DataFrame(so_2)
so_2= so_2.rename(columns={'team2':'team1'})

# %%
frames=[so_1,so_2]

# %%
sup= pd.concat(frames)

# %%
so_team= sup.groupby(['team1'])['team1'].agg('count')

# %%
so_team= pd.DataFrame(so_team)

# %%
so_win= so.groupby(['winner'])['winner'].agg('count')

# %%
so_win= pd.DataFrame(so_win)

# %%
so_win
# Out:
#                              winner
# winner
# Delhi Capitals                    1
# Kings XI Punjab                   2
# Mumbai Indians                    2
# Rajasthan Royals                  2
# Royal Challengers Bangalore       1
# Sunrisers Hyderabad               1

# %%
so_team.to_csv('super_team.csv')

# %%
super_over= pd.read_csv('super_team.csv')

# %%
super_over
# Out:
#                           team  Matches  Won  Loss
# 0          Chennai Super Kings        1    0     1
# 1               Delhi Capitals        1    1     0
# 2             Delhi Daredevils        1    0     1
# 3                Gujarat Lions        1    0     1
# 4              Kings XI Punjab        2    2     0
# 5        Kolkata Knight Riders        3    0     3
# 6               Mumbai Indians        2    2     0
# 7             Rajasthan Royals        3    2     1
# 8  Royal Challengers Bangalore        2    1     1
# 9          Sunrisers Hyderabad        2    1     1

# %% [markdown]
# # Highest Wicket Taker

# %%
wic_ball= deliveries.copy()

# %%
wic_ball= wic_ball.rename(columns={'player_dismissed':'Wickets'})

# %%
wic_ball= wic_ball.groupby(['bowler'])['Wickets'].agg('count')

# %%
wic_ball=pd.DataFrame(wic_ball)

# %%
wic_ball.sort_values(by='Wickets', ascending=False).head(10)
# Out:
#                  Wickets
# bowler
# SL Malinga           188
# DJ Bravo             168
# A Mishra             165
# Harbhajan Singh      161
# PP Chawla            156
# B Kumar              141
# R Ashwin             138
# SP Narine            137
# UT Yadav             136
# R Vinay Kumar        127

# %%
# Runs Conceded

# %%
run_con= deliveries.copy()

# %%
run_con= run_con.rename(columns={'total_runs': 'Runs_Conceded'})

# %%
run_con= run_con.groupby(['bowler'])['Runs_Conceded'].agg('sum')

# %%
run_con= pd.DataFrame(run_con)

# %%
# Balls Bowled

# %%
ov_bo= deliveries.copy()

# %%
ov_bo= ov_bo.groupby(['bowler'])['over'].agg('count')

# %%
ov_bo= pd.DataFrame(ov_bo)

# %%
ov_bo= ov_bo.rename(columns={'over': 'Ball'})

# %%
# Join into single table

# %%
run_con['ball']= ov_bo['Ball'].values

# %%
run_con
# Out:
#                    Runs_Conceded  ball
# bowler
# A Ashish Reddy               400   270
# A Chandila                   245   234
# A Choudhary                  144   108
# A Dananjaya                   48    25
# A Flintoff                   106    66
# A Joseph                      94    55
# A Kumble                    1089   983
# A Mishra                    3850  3172
# A Mithun                     477   312
# A Nehra                     2537  1974
# A Nel                         31    18
# A Roy                         14    15
# A Singh                      769   551
# A Symonds                    694   540
# A Uniyal                      67    38
# A Zampa                      281   225
# AA Chavan                    339   255
# AA Jhunjhunwala              130    88
# AA Kazi                       21    13
# AA Noffke                     41    25
# AB Agarkar                  1174   820
# AB Dinda                    2103  1589
# AB McDonald                  263   188
# ...

# %% [markdown]
# # Lowest Economy (16-20 ovr)

# %%
run_con['economy']=np.nan
for i in range(0,len(run_con['ball'])):
    run_con['economy'][i]= round((run_con['Runs_Conceded'][i] / (run_con['ball'][i]/6)),1)
# Out:
# C:\Users\Samruddhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
run_con.head()
# Out:
#                 Runs_Conceded  ball  economy
# bowler
# A Ashish Reddy            400   270      8.9
# A Chandila                245   234      6.3
# A Choudhary               144   108      8.0
# A Dananjaya                48    25     11.5
# A Flintoff                106    66      9.6

# %%
pro.head()
# Out:
#      match_id  inning         batting_team                 bowling_team  over  \
# 99          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    17
# 100         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    17
# 101         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    17
# 102         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    17
# 103         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    17
#
#      ball       batsman   non_striker    bowler  is_super_over  ...  bye_runs  \
# 99      1      DJ Hooda  Yuvraj Singh  TS Mills              0  ...         0
# 100     2  Yuvraj Singh      DJ Hooda  TS Mills              0  ...         0
# 101     3  Yuvraj Singh      DJ Hooda  TS Mills              0  ...         0
# 102     4  Yuvraj Singh      DJ Hooda  TS Mills              0  ...         0
# 103     5      DJ Hooda  Yuvraj Singh  TS Mills              0  ...         0
#
# ...

# %%
low_eco= pro.groupby(['bowler'])['total_runs'].agg('sum')

# %%
low_eco= pd.DataFrame(low_eco)

# %%
eco_1= pro.groupby(['bowler'])['ball'].agg('count')

# %%
eco_1= pd.DataFrame(eco_1)

# %%
eco_1['ball'].head()
# Out:
# bowler
# A Ashish Reddy    75
# A Chandila         6
# A Choudhary       27
# A Flintoff        18
# A Joseph           4
# Name: ball, dtype: int64

# %%
low_eco['ball']= eco_1['ball'].values

# %%
low_eco= pd.DataFrame(low_eco)

# %%
low_eco['economy']= np.nan
for i in range(0,len(low_eco['ball'])):
    low_eco['economy'][i]= round((low_eco['total_runs'][i] / (low_eco['ball'][i]/6)),1)
# Out:
# C:\Users\Samruddhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
low_eco.head()
# Out:
#                 total_runs  ball  economy
# bowler
# A Ashish Reddy         123    75      9.8
# A Chandila               6     6      6.0
# A Choudhary             40    27      8.9
# A Flintoff              52    18     17.3
# A Joseph                 5     4      7.5

# %%
low_eco= low_eco[low_eco['ball']>=100].sort_values(by='economy', ascending= True).head(10)

# %%
low_eco.drop(['total_runs','ball'],axis=1, inplace=True)

# %%
low_eco
# Out:
#                  economy
# bowler
# Rashid Khan          7.4
# DE Bollinger         7.4
# WD Parnell           7.8
# SL Malinga           7.8
# MA Starc             7.8
# A Kumble             7.9
# SP Narine            8.0
# SW Tait              8.1
# Harbhajan Singh      8.1
# Harmeet Singh        8.2

# %% [markdown]
# # Team Stats

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
uni= matches['season'].unique()

# %%
match= matches.copy()

# %%
match_1= match.rename(columns={'id':'matches'})

# %%
match_1= match_1.groupby(['season'])['matches'].agg('count')

# %%
match_season= pd.DataFrame(match_1)

# %%
match_season
# Out:
#         matches
# season
# 2008         58
# 2009         57
# 2010         60
# 2011         73
# 2012         74
# 2013         76
# 2014         60
# 2015         59
# 2016         60
# 2017         59
# 2018         60
# 2019         60

# %%
match.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
a=[]
for i in uni:
    match_2= match[match['season']== i].tail(1)
    b= match_2['id']
    a.append(b)

# %%
a
# Out:
# [58    59
#  Name: id, dtype: int64, 116    117
#  Name: id, dtype: int64, 173    174
#  Name: id, dtype: int64, 233    234
#  Name: id, dtype: int64, 306    307
#  Name: id, dtype: int64, 380    381
#  Name: id, dtype: int64, 456    457
#  Name: id, dtype: int64, 516    517
#  Name: id, dtype: int64, 575    576
#  Name: id, dtype: int64, 635    636
#  Name: id, dtype: int64, 695    7953
#  Name: id, dtype: int64, 755    11415
#  Name: id, dtype: int64]

# %%
# IPL Winners

# %%
lis= [58,116,173,233,306,380,456,516,575,635,695,755]

# %%
team =[]
year = []
for i in lis:
    winner=match['winner'][i]
    team.append(winner)
    t= match['season'][i]
    year.append(t)

# %%
year
# Out:
# [2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018, 2019]

# %%
winners= pd.DataFrame(year,team)

# %%
winners= winners.rename(columns={'0':'season'})

# %%
winners.to_csv('ipl_winners.csv')

# %%
winner= pd.read_csv('ipl_winners.csv')

# %%
winner.sort_values(by= 'season', ascending= True)
# Out:
#                      team  season
# 1        Rajasthan Royals    2008
# 2         Deccan Chargers    2009
# 3     Chennai Super Kings    2010
# 4     Chennai Super Kings    2011
# 5   Kolkata Knight Riders    2012
# 6          Mumbai Indians    2013
# 7   Kolkata Knight Riders    2014
# 8          Mumbai Indians    2015
# 9     Sunrisers Hyderabad    2016
# 0          Mumbai Indians    2017
# 10    Chennai Super Kings    2018
# 11         Mumbai Indians    2019

# %%
# Most titles

# %%
winner= winner.groupby(['team'])['season'].agg('count')

# %%
winner=pd.DataFrame(winner)

# %%
winner.sort_values(by='season', ascending=False)
# Out:
#                        season
# team
# Mumbai Indians              4
# Chennai Super Kings         3
# Kolkata Knight Riders       2
# Deccan Chargers             1
# Rajasthan Royals            1
# Sunrisers Hyderabad         1

# %%
finals= match[match.index.isin(lis)]

# %%
finals=finals.sort_values(by='season')
finals
# Out:
#         id  season          city        date                team1  \
# 116    117    2008        Mumbai  2008-06-01  Chennai Super Kings
# 173    174    2009  Johannesburg  2009-05-24      Deccan Chargers
# 233    234    2010        Mumbai  2010-04-25  Chennai Super Kings
# 306    307    2011       Chennai  2011-05-28  Chennai Super Kings
# 380    381    2012       Chennai  2012-05-27  Chennai Super Kings
# 456    457    2013       Kolkata  2013-05-26       Mumbai Indians
# 516    517    2014     Bangalore  2014-06-01      Kings XI Punjab
# 575    576    2015       Kolkata  2015-05-24       Mumbai Indians
# 635    636    2016     Bangalore  2016-05-29  Sunrisers Hyderabad
# 58      59    2017     Hyderabad  2017-05-21       Mumbai Indians
# 695   7953    2018        Mumbai    27/05/18  Sunrisers Hyderabad
# 755  11415    2019     Hyderabad    12/05/19       Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
final= finals.copy()

# %%
final= final.iloc[:,[2,4,5,6,7,8]]

# %%
final
# Out:
#              city                team1                        team2  \
# 116        Mumbai  Chennai Super Kings             Rajasthan Royals
# 173  Johannesburg      Deccan Chargers  Royal Challengers Bangalore
# 233        Mumbai  Chennai Super Kings               Mumbai Indians
# 306       Chennai  Chennai Super Kings  Royal Challengers Bangalore
# 380       Chennai  Chennai Super Kings        Kolkata Knight Riders
# 456       Kolkata       Mumbai Indians          Chennai Super Kings
# 516     Bangalore      Kings XI Punjab        Kolkata Knight Riders
# 575       Kolkata       Mumbai Indians          Chennai Super Kings
# 635     Bangalore  Sunrisers Hyderabad  Royal Challengers Bangalore
# 58      Hyderabad       Mumbai Indians       Rising Pune Supergiant
# 695        Mumbai  Sunrisers Hyderabad          Chennai Super Kings
# 755     Hyderabad       Mumbai Indians          Chennai Super Kings
#
#                      toss_winner toss_decision  result
# ...

# %%
go_1= final.groupby(['team1'])['team1'].agg('count')

# %%
go_2= final.groupby(['team2'])['team2'].agg('count')

# %%
go_1
# Out:
# team1
# Chennai Super Kings    4
# Deccan Chargers        1
# Kings XI Punjab        1
# Mumbai Indians         4
# Sunrisers Hyderabad    2
# Name: team1, dtype: int64

# %%
go_2
# Out:
# team2
# Chennai Super Kings            4
# Kolkata Knight Riders          2
# Mumbai Indians                 1
# Rajasthan Royals               1
# Rising Pune Supergiant         1
# Royal Challengers Bangalore    3
# Name: team2, dtype: int64

# %%
sim= [['Chennai Super Kings',8,3,5],['Mumbai Indians',5,4,1],['Royal Challengers Bangalore',3,0,3],['Kolkata Knight Riders',2,2,0],['Sunrisers Hyderabad',2,1,1],['Rajasthan Royals',1,1,0],['Kings XI Punjab',1,0,1],['Deccan Chargers',1,1,0],['Rising Pune Supergiant',1,0,1]]

# %%
win_loss= pd.DataFrame(sim, columns = ['Team','Finals_Played','Won','Lost'])

# %%
win_loss
# Out:
#                           Team  Finals_Played  Won  Lost
# 0          Chennai Super Kings              8    3     5
# 1               Mumbai Indians              5    4     1
# 2  Royal Challengers Bangalore              3    0     3
# 3        Kolkata Knight Riders              2    2     0
# 4          Sunrisers Hyderabad              2    1     1
# 5             Rajasthan Royals              1    1     0
# 6              Kings XI Punjab              1    0     1
# 7              Deccan Chargers              1    1     0
# 8       Rising Pune Supergiant              1    0     1

# %%
# Player of the match

# %%
pom= matches.groupby(['player_of_match'])['player_of_match'].agg('count')

# %%
pom= pd.DataFrame(pom)

# %%
pom= pom.rename(columns={'player_of_match':'award_won'})

# %%
pom.sort_values(by='award_won',ascending= False).head(10)
# Out:
#                  award_won
# player_of_match
# CH Gayle                21
# AB de Villiers          20
# MS Dhoni                17
# DA Warner               17
# RG Sharma               17
# YK Pathan               16
# SR Watson               15
# SK Raina                14
# G Gambhir               13
# MEK Hussey              12

# %%
# Total matches won

# %%
tmw= matches.groupby(['winner'])['winner'].agg('count')
tmw=pd.DataFrame(tmw)
tmw= tmw.rename(columns={'winner':'matches_won'})
tmw.sort_values(by='matches_won',ascending=False).head(8)
# Out:
#                              matches_won
# winner
# Mumbai Indians                       109
# Chennai Super Kings                  100
# Kolkata Knight Riders                 92
# Royal Challengers Bangalore           84
# Kings XI Punjab                       82
# Rajasthan Royals                      75
# Delhi Daredevils                      67
# Sunrisers Hyderabad                   58

# %%
# Most Popular Umpire

# %%
pop_ump_1= matches.iloc[:,[15,16]].dropna()
pop_ump_1=pd.DataFrame(pop_ump_1)

# %%
pop_ump_1.to_csv('umpires.csv',index=False)

# %%
pop_ump= pd.read_csv('umpires.csv')

# %%
pop_ump= pop_ump.groupby(['umpire1'])['umpire1'].agg('count')
pop_ump=pd.DataFrame(pop_ump)
pop_ump= pop_ump.rename(columns={'umpire1':'matches'})

# %%
pop_ump.sort_values(by='matches',ascending=False).head(3)
# Out:
#                  matches
# umpire1
# S Ravi               106
# HDPK Dharmasena       87
# C Shamshuddin         73

# %%
# Most Popular Venue

# %%
fav= matches.iloc[:,[2,14]]

# %%
fav.head()
# Out:
#         city                                      venue
# 0  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 1       Pune    Maharashtra Cricket Association Stadium
# 2     Rajkot     Saurashtra Cricket Association Stadium
# 3     Indore                     Holkar Cricket Stadium
# 4  Bangalore                      M Chinnaswamy Stadium

# %%
pop_venue= fav.groupby(['venue'])['venue'].agg('count')
pop_venue=pd.DataFrame(pop_venue)
pop_venue= pop_venue.rename(columns={'venue':'matches_played'})

# %%
pop_venue.sort_values(by='matches_played', ascending=False).head(5)
# Out:
#                                            matches_played
# venue
# Eden Gardens                                           77
# Wankhede Stadium                                       73
# M Chinnaswamy Stadium                                  73
# Feroz Shah Kotla                                       67
# Rajiv Gandhi International Stadium, Uppal              56
